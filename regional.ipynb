# %%
#importing dependencies
import pandas as pd
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import func
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
pymysql.install_as_MySQLdb()

engine = create_engine("mysql://root:joker123@localhost/ETLProject")
conn = engine.connect()

# %%
#converting university csv into dataframe
university="Desktop/college-salaries/salaries-by-region.csv"

universitydf=pd.read_csv(university)

print(universitydf)
# Out:
#                                            School Name        Region  \
# 0                                  Stanford University    California
# 1             California Institute of Technology (CIT)    California
# 2                                  Harvey Mudd College    California
# 3                   University of California, Berkeley    California
# 4                                   Occidental College    California
# 5                             Cal Poly San Luis Obispo    California
# 6       University of California at Los Angeles (UCLA)    California
# 7           University of California, San Diego (UCSD)    California
# 8                                       Pomona College    California
# 9              University of Southern California (USC)    California
# 10                     University of California, Davis    California
# 11              University of California, Irvine (UCI)    California
# 12                    San Jose State University (SJSU)    California
# ...

# %%
#dropping duplicate universities
universitydf.drop_duplicates()

print(universitydf)
# Out:
#                                            School Name        Region  \
# 0                                  Stanford University    California
# 1             California Institute of Technology (CIT)    California
# 2                                  Harvey Mudd College    California
# 3                   University of California, Berkeley    California
# 4                                   Occidental College    California
# 5                             Cal Poly San Luis Obispo    California
# 6       University of California at Los Angeles (UCLA)    California
# 7           University of California, San Diego (UCSD)    California
# 8                                       Pomona College    California
# 9              University of Southern California (USC)    California
# 10                     University of California, Davis    California
# 11              University of California, Irvine (UCI)    California
# 12                    San Jose State University (SJSU)    California
# ...

# %%
#cleaning names of the universities

# %%
#university list table
universitylist = pd.read_sql_query("Select * from college_list", con=engine)
universitylist

# %%
#merging tables
merged = universitydf.merge(clist, left_on="School Name", right_on="college_name", how='left')
#merged['college_list_id']= merged['college_list_id'].astype('int')
merged.head()

# %%
#converting list id to integer
merged.fillna(value=0, inplace=True)
merged['college_list_id'] = merged['college_list_id'].astype('int')
merged.head()

# %%
#converting state id to int
merged.fillna(value=0, inplace=True)
merged['state_id'] = merged['state_id'].astype('int')
merged.head()

# %%
#column dropping
merged.drop(columns={'college_name','college_city','state_id','Region'}, inplace=True)
merged

# %%
#converting into floats

# %%
#column renaming
merged.rename(columns={'Mid-Career 10th Percentile Salary': 'prcnt_ten',
                      'Mid-Career 25th Percentile Salary':'prcnt_tf',
                      'Mid-Career 75th Percentile Salary': 'prcnt_sf',
                      'Mid-Career 90th Percentile Salary': 'prcnt_nn'}, inplace=True)
merged.head()
